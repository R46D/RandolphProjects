# %%
#Opening the file
#directory might be different for different users

file=open("D:/Exercise files/Internshala/Python Project__ File Handling and String Manipulation/conv.txt","r")

#reading the file

file2=file.read()

print(file2)
# Out:
# WILL: Iâ€™ve never seen wildlings do a thing like this. Iâ€™ve never seen a thing like this, not ever in my life.
#
# WAYMAR ROYCE: How close did you get?
#
# WILL: Close as any man would.
#
# GARED: We should head back to the wall.
#
# ROYCE: Do the dead frighten you?
#
# GARED: Our orders were to track the wildlings. We tracked them. They wonâ€™t trouble us no more.
#
# ROYCE: You donâ€™t think heâ€™ll ask us how they died? Get back on your horse.
#
# WILL: Whatever did it to them could do it to us. They even killed the children.
#
# ROYCE: Itâ€™s a good thing weâ€™re not children. You want to run away south, run away. Of course, they will behead you as a deserter â€¦ If I donâ€™t catch you first. Get back on your horse. I wonâ€™t say it again.
#
# ROYCE: Your dead men seem to have moved camp.
#
# WILL: They were here.
#
# GARED: See where they went.
#
# ROYCE: What is it?
#
# JON: Go on. Fatherâ€™s watching.
#
# JON: And your mother.
#
# ...

# %%
#creating a list of lines by splitting the sentences by next line
clean_file=file2.split("\n")
print(clean_file)
# Out:
# ['WILL: Iâ€™ve never seen wildlings do a thing like this. Iâ€™ve never seen a thing like this, not ever in my life.', '', 'WAYMAR ROYCE: How close did you get?', '', 'WILL: Close as any man would.', '', 'GARED: We should head back to the wall.', '', 'ROYCE: Do the dead frighten you?', '', 'GARED: Our orders were to track the wildlings. We tracked them. They wonâ€™t trouble us no more.', '', 'ROYCE: You donâ€™t think heâ€™ll ask us how they died? Get back on your horse.', '', 'WILL: Whatever did it to them could do it to us. They even killed the children.', '', 'ROYCE: Itâ€™s a good thing weâ€™re not children. You want to run away south, run away. Of course, they will behead you as a deserter â€¦ If I donâ€™t catch you first. Get back on your horse. I wonâ€™t say it again.', '', 'ROYCE: Your dead men seem to have moved camp.', '', 'WILL: They were here.', '', 'GARED: See where they went.', '', 'ROYCE: What is it?', '', 'JON: Go on. Fatherâ€™s watching.', '', 'JON: And your mother.', '
# ...

# %%
#removing empty values from the list of sentences
clean_file2=[x for x in clean_file if x]
print(clean_file2)
# Out:
# ['WILL: Iâ€™ve never seen wildlings do a thing like this. Iâ€™ve never seen a thing like this, not ever in my life.', 'WAYMAR ROYCE: How close did you get?', 'WILL: Close as any man would.', 'GARED: We should head back to the wall.', 'ROYCE: Do the dead frighten you?', 'GARED: Our orders were to track the wildlings. We tracked them. They wonâ€™t trouble us no more.', 'ROYCE: You donâ€™t think heâ€™ll ask us how they died? Get back on your horse.', 'WILL: Whatever did it to them could do it to us. They even killed the children.', 'ROYCE: Itâ€™s a good thing weâ€™re not children. You want to run away south, run away. Of course, they will behead you as a deserter â€¦ If I donâ€™t catch you first. Get back on your horse. I wonâ€™t say it again.', 'ROYCE: Your dead men seem to have moved camp.', 'WILL: They were here.', 'GARED: See where they went.', 'ROYCE: What is it?', 'JON: Go on. Fatherâ€™s watching.', 'JON: And your mother.', 'SEPTA MORDANE: Fine work, as always. Well done.', 'SANSA
# ...

# %%
#splitting the speaker(aka character) and words said into a list
#This creates a list inside the main list and the first sub value is the name of the character and the second sub value are the words spoken

candw=[i.split(":") for i in clean_file2] 
print(candw)
# Out:
# [['WILL', ' Iâ€™ve never seen wildlings do a thing like this. Iâ€™ve never seen a thing like this, not ever in my life.'], ['WAYMAR ROYCE', ' How close did you get?'], ['WILL', ' Close as any man would.'], ['GARED', ' We should head back to the wall.'], ['ROYCE', ' Do the dead frighten you?'], ['GARED', ' Our orders were to track the wildlings. We tracked them. They wonâ€™t trouble us no more.'], ['ROYCE', ' You donâ€™t think heâ€™ll ask us how they died? Get back on your horse.'], ['WILL', ' Whatever did it to them could do it to us. They even killed the children.'], ['ROYCE', ' Itâ€™s a good thing weâ€™re not children. You want to run away south, run away. Of course, they will behead you as a deserter â€¦ If I donâ€™t catch you first. Get back on your horse. I wonâ€™t say it again.'], ['ROYCE', ' Your dead men seem to have moved camp.'], ['WILL', ' They were here.'], ['GARED', ' See where they went.'], ['ROYCE', ' What is it?'], ['JON', ' Go on. Fatherâ€™s watching.'], ['JON', ' An
# ...

# %%
#The first sub-value of the list after the split will be the characters name
charduplicates=[i.split(":")[0] for i in clean_file2]
print(charduplicates)
# Out:
# ['WILL', 'WAYMAR ROYCE', 'WILL', 'GARED', 'ROYCE', 'GARED', 'ROYCE', 'WILL', 'ROYCE', 'ROYCE', 'WILL', 'GARED', 'ROYCE', 'JON', 'JON', 'SEPTA MORDANE', 'SANSA', 'SEPTA MORDANE', 'NED', 'JON', 'ROBB', 'CASSEL', 'NED', 'CATELYN', 'NED', 'CASSEL', 'NED', 'CATELYN', 'NED', 'ROBB', 'NED', 'JON', 'NED', 'JON', 'NED', 'BRAN', 'NED', 'BRAN', 'NED', 'BRAN', 'NED', 'BRAN', 'NED', 'JON', 'THEON', 'NED', 'THEON', 'NED', 'NED', 'ROBB', 'JON', 'JON', 'BRAN', 'CASSEL', 'NED', 'THEON', 'BRAN', 'ROBB', 'THEON', 'BRAN', 'NED', 'JON', 'NED', 'BRAN', 'JON', 'ROBB', 'CERSEI', 'JAIME', 'CERSEI', 'JAIME', 'CERSEI', 'JAIME', 'CATELYN', 'NED', 'CATELYN', 'NED', 'CATELYN', 'NED', 'ROBB', 'THEON', 'ROBB', 'CATELYN', 'BRAN', 'CATELYN', 'BRAN', 'CATELYN', 'NED', 'ROBERT', 'ROBERT', 'CATELYN', 'ROBERT', 'NED', 'ARYA', 'SANSA', 'ROBERT', 'ARYA', 'ROBERT', 'ARYA', 'SANSA', 'NED', 'CATELYN', 'ROBERT', 'CERSEI', 'ROBERT', 'ARYA', 'CERSEI', 'NED', 'ROBERT', 'NED', 'ROBERT', 'NED']

# %%
#converting the list into set to remove duplicates
characters=set(charduplicates)

#Now converting it back to a list and we can show the characters name without duplicates
characters=list(characters)
print("List of characters are: ",characters)
# Out:
# List of characters are:  ['ROBERT', 'GARED', 'ARYA', 'THEON', 'JAIME', 'ROBB', 'JON', 'CATELYN', 'SANSA', 'CASSEL', 'WAYMAR ROYCE', 'SEPTA MORDANE', 'BRAN', 'WILL', 'CERSEI', 'ROYCE', 'NED']

# %%
#Creating a list variable for each character and saving sentences spoke by them in the variable

x=len(clean_file2)
character_1=[]
character_2=[]
character_3=[]
character_4=[]
character_5=[]
character_6=[]
character_7=[]
character_8=[]
character_9=[]
character_10=[]
character_11=[]
character_12=[]
character_13=[]
character_14=[]
character_15=[]
character_16=[]
character_17=[]

for i in range(0,x-1):
    if candw[i][0] == characters[0]:
        character_1.append(candw[i][1])
    elif candw[i][0] == characters[1]:
        character_2.append(candw[i][1]) 
    elif candw[i][0] == characters[2]:
        character_3.append(candw[i][1]) 
    elif candw[i][0] == characters[3]:
        character_4.append(candw[i][1]) 
    elif candw[i][0] == characters[4]:
        character_5.append(candw[i][1]) 
    elif candw[i][0] == characters[5]:
        character_6.append(candw[i][1]) 
    elif candw[i][0] == characters[6]:
        character_7.append(candw[i][1]) 
    elif candw[i][0] == characters[7]:
        character_8.append(candw[i][1]) 
    elif candw[i][0] == characters[8]:
        character_9.append(candw[i][1]) 
    elif candw[i][0] == characters[9]:
        character_10.append(candw[i][1])        
    elif candw[i][0] == characters[10]:
        character_11.append(candw[i][1]) 
    elif candw[i][0] == characters[11]:
        character_12.append(candw[i][1]) 
    elif candw[i][0] == characters[12]:
        character_13.append(candw[i][1]) 
    elif candw[i][0] == characters[13]:
        character_14.append(candw[i][1])         
    elif candw[i][0] == characters[14]:
        character_15.append(candw[i][1])  
    elif candw[i][0] == characters[15]:
        character_16.append(candw[i][1]) 
    else:
        character_17.append(candw[i][1])

# %%
character_2
# Out:
# [' We should head back to the wall.',
#  ' Our orders were to track the wildlings. We tracked them. They wonâ€™t trouble us no more.',
#  ' See where they went.']

# %%
#Seperating the words based on spaces

character_1=[i.split(" ") for i in character_1] 
character_2=[i.split(" ") for i in character_2] 
character_3=[i.split(" ") for i in character_3] 
character_4=[i.split(" ") for i in character_4] 
character_5=[i.split(" ") for i in character_5] 
character_6=[i.split(" ") for i in character_6] 
character_7=[i.split(" ") for i in character_7] 
character_8=[i.split(" ") for i in character_8] 
character_9=[i.split(" ") for i in character_9] 
character_10=[i.split(" ") for i in character_10] 
character_11=[i.split(" ") for i in character_11] 
character_12=[i.split(" ") for i in character_12] 
character_13=[i.split(" ") for i in character_13] 
character_14=[i.split(" ") for i in character_14] 
character_15=[i.split(" ") for i in character_15] 
character_16=[i.split(" ") for i in character_16] 
character_17=[i.split(" ") for i in character_17]

# %%
#Merging the sub-lists into one big list

import numpy as np
character_1= list(np.concatenate(character_1))
character_2= list(np.concatenate(character_2))
character_3= list(np.concatenate(character_3))
character_4= list(np.concatenate(character_4))
character_5= list(np.concatenate(character_5))
character_6= list(np.concatenate(character_6))
character_7= list(np.concatenate(character_7))
character_8= list(np.concatenate(character_8))
character_9= list(np.concatenate(character_9))
character_10= list(np.concatenate(character_10))
character_11= list(np.concatenate(character_11))
character_12= list(np.concatenate(character_12))
character_13= list(np.concatenate(character_13))
character_14= list(np.concatenate(character_14))
character_15= list(np.concatenate(character_15))
character_16= list(np.concatenate(character_16))
character_17= list(np.concatenate(character_17))

# %%
#Removing the special characters from the words

character_1=[i.replace("?","") for i in character_1] 
character_2=[i.replace("?","") for i in character_2]
character_3=[i.replace("?","") for i in character_3] 
character_4=[i.replace("?","") for i in character_4] 
character_5=[i.replace("?","") for i in character_5] 
character_6=[i.replace("?","") for i in character_6] 
character_7=[i.replace("?","") for i in character_7] 
character_8=[i.replace("?","") for i in character_8] 
character_9=[i.replace("?","") for i in character_9] 
character_10=[i.replace("?","") for i in character_10] 
character_11=[i.replace("?","") for i in character_11] 
character_12=[i.replace("?","") for i in character_12] 
character_13=[i.replace("?","") for i in character_13] 
character_14=[i.replace("?","") for i in character_14] 
character_15=[i.replace("?","") for i in character_15] 
character_16=[i.replace("?","") for i in character_16]
character_17=[i.replace("?","") for i in character_17]

character_1=[i.replace("!","") for i in character_1] 
character_2=[i.replace("!","") for i in character_2]
character_3=[i.replace("!","") for i in character_3] 
character_4=[i.replace("!","") for i in character_4] 
character_5=[i.replace("!","") for i in character_5] 
character_6=[i.replace("!","") for i in character_6] 
character_7=[i.replace("!","") for i in character_7] 
character_8=[i.replace("!","") for i in character_8] 
character_9=[i.replace("!","") for i in character_9] 
character_10=[i.replace("!","") for i in character_10] 
character_11=[i.replace("!","") for i in character_11] 
character_12=[i.replace("!","") for i in character_12] 
character_13=[i.replace("!","") for i in character_13] 
character_14=[i.replace("!","") for i in character_14] 
character_15=[i.replace("!","") for i in character_15] 
character_16=[i.replace("!","") for i in character_16]
character_17=[i.replace("!","") for i in character_17]

character_1=[i.replace(".","") for i in character_1] 
character_2=[i.replace(".","") for i in character_2]
character_3=[i.replace(".","") for i in character_3] 
character_4=[i.replace(".","") for i in character_4] 
character_5=[i.replace(".","") for i in character_5] 
character_6=[i.replace(".","") for i in character_6] 
character_7=[i.replace(".","") for i in character_7] 
character_8=[i.replace(".","") for i in character_8] 
character_9=[i.replace(".","") for i in character_9] 
character_10=[i.replace(".","") for i in character_10] 
character_11=[i.replace(".","") for i in character_11] 
character_12=[i.replace(".","") for i in character_12] 
character_13=[i.replace(".","") for i in character_13] 
character_14=[i.replace(".","") for i in character_14] 
character_15=[i.replace(".","") for i in character_15] 
character_16=[i.replace(".","") for i in character_16]
character_17=[i.replace(".","") for i in character_17]

character_1=[i.replace(",","") for i in character_1] 
character_2=[i.replace(",","") for i in character_2]
character_3=[i.replace(",","") for i in character_3] 
character_4=[i.replace(",","") for i in character_4] 
character_5=[i.replace(",","") for i in character_5] 
character_6=[i.replace(",","") for i in character_6] 
character_7=[i.replace(",","") for i in character_7] 
character_8=[i.replace(",","") for i in character_8] 
character_9=[i.replace(",","") for i in character_9] 
character_10=[i.replace(",","") for i in character_10] 
character_11=[i.replace(",","") for i in character_11] 
character_12=[i.replace(",","") for i in character_12] 
character_13=[i.replace(",","") for i in character_13] 
character_14=[i.replace(",","") for i in character_14] 
character_15=[i.replace(",","") for i in character_15] 
character_16=[i.replace(",","") for i in character_16]
character_17=[i.replace(",","") for i in character_17]

# %%
#Converting all the words into the same case to find unique words 

character_1 = [character_1.lower() for character_1 in character_1]
character_2 = [character_2.lower() for character_2 in character_2]
character_3 = [character_3.lower() for character_3 in character_3]
character_4 = [character_4.lower() for character_4 in character_4]
character_5 = [character_5.lower() for character_5 in character_5]
character_6 = [character_6.lower() for character_6 in character_6]
character_7 = [character_7.lower() for character_7 in character_7]
character_8 = [character_8.lower() for character_8 in character_8]
character_9 = [character_9.lower() for character_9 in character_9]
character_10 = [character_10.lower() for character_10 in character_10]
character_11 = [character_11.lower() for character_11 in character_11]
character_12 = [character_12.lower() for character_12 in character_12]
character_13 = [character_13.lower() for character_13 in character_13]
character_14 = [character_14.lower() for character_14 in character_14]
character_15 = [character_15.lower() for character_15 in character_15]
character_16 = [character_16.lower() for character_16 in character_16]
character_17 = [character_17.lower() for character_17 in character_17]

# %%
#Removing dupicate words

character_1= set((character_1))
character_2= set((character_2))
character_3= set((character_3))
character_4= set((character_4))
character_5= set((character_5))
character_6= set((character_6))
character_7= set((character_7))
character_8= set((character_8))
character_9= set((character_9))
character_10= set((character_10))
character_11= set((character_11))
character_12= set((character_12))
character_13= set((character_13))
character_14= set((character_14))
character_15= set((character_15))
character_16= set((character_16))
character_17= set((character_17))

character_1= list((character_1))
character_2= list((character_2))
character_3= list((character_3))
character_4= list((character_4))
character_5= list((character_5))
character_6= list((character_6))
character_7= list((character_7))
character_8= list((character_8))
character_9= list((character_9))
character_10= list((character_10))
character_11= list((character_11))
character_12= list((character_12))
character_13= list((character_13))
character_14= list((character_14))
character_15= list((character_15))
character_16= list((character_16))
character_17= list((character_17))

# %%
#Removing empty elements


character_1=[x for x in character_1 if x]
character_2=[x for x in character_2 if x]
character_3=[x for x in character_3 if x]
character_4=[x for x in character_4 if x]
character_5=[x for x in character_5 if x]
character_6=[x for x in character_6 if x]
character_7=[x for x in character_7 if x]
character_8=[x for x in character_8 if x]
character_9=[x for x in character_9 if x]
character_10=[x for x in character_10 if x]
character_11=[x for x in character_11 if x]
character_12=[x for x in character_12 if x]
character_13=[x for x in character_13 if x]
character_14=[x for x in character_14 if x]
character_15=[x for x in character_15 if x]
character_16=[x for x in character_16 if x]
character_17=[x for x in character_17 if x]

# %%
#Sorting the values
character_1.sort()
character_2.sort()
character_3.sort()
character_4.sort()
character_5.sort()
character_6.sort()
character_7.sort()
character_8.sort()
character_9.sort()
character_10.sort()
character_11.sort()
character_12.sort()
character_13.sort()
character_14.sort()
character_15.sort()
character_16.sort()
character_17.sort()

# %%
#Now writing the words said by characters into file corresponding to their name




with open('D:/Exercise files/Internshala/Python Project__ File Handling and String Manipulation/Output/%s.txt' %characters[0], 'a') as f:
    for words in character_1:
            f.write(words + "\n")        

with open('D:/Exercise files/Internshala/Python Project__ File Handling and String Manipulation/Output/%s.txt' %characters[1], 'a') as f:
    for words in character_2:
          f.write(words + "\n")

with open('D:/Exercise files/Internshala/Python Project__ File Handling and String Manipulation/Output/%s.txt' %characters[2], 'a') as f:
     for words in character_3:
            f.write(words + "\n") 

with open('D:/Exercise files/Internshala/Python Project__ File Handling and String Manipulation/Output/%s.txt' %characters[3], 'a') as f:
     for words in character_4:
            f.write(words + "\n") 

with open('D:/Exercise files/Internshala/Python Project__ File Handling and String Manipulation/Output/%s.txt' %characters[4], 'a') as f:
     for words in character_5:
            f.write(words + "\n")

with open('D:/Exercise files/Internshala/Python Project__ File Handling and String Manipulation/Output/%s.txt' %characters[5], 'a') as f:
     for words in character_6:
            f.write(words + "\n") 

with open('D:/Exercise files/Internshala/Python Project__ File Handling and String Manipulation/Output/%s.txt' %characters[6], 'a') as f:
     for words in character_7:
            f.write(words + "\n") 

with open('D:/Exercise files/Internshala/Python Project__ File Handling and String Manipulation/Output/%s.txt'%characters[7], 'a') as f:
      for words in character_8:
            f.write(words + "\n")
                
with open('D:/Exercise files/Internshala/Python Project__ File Handling and String Manipulation/Output/%s.txt' %characters[8], 'a') as f:
    for words in character_9:
          f.write(words + "\n")
                
with open('D:/Exercise files/Internshala/Python Project__ File Handling and String Manipulation/Output/%s.txt' %characters[9], 'a') as f:
      for words in character_10:
            f.write(words + "\n")
                
with open('D:/Exercise files/Internshala/Python Project__ File Handling and String Manipulation/Output/%s.txt' %characters[10], 'a') as f:
       for words in character_11:
            f.write(words + "\n")
                
with open('D:/Exercise files/Internshala/Python Project__ File Handling and String Manipulation/Output/%s.txt' %characters[11], 'a') as f:
      for words in character_12:
            f.write(words + "\n") 
        
with open('D:/Exercise files/Internshala/Python Project__ File Handling and String Manipulation/Output/%s.txt' %characters[12], 'a') as f:
        for words in character_13:
            f.write(words + "\n")
        
with open('D:/Exercise files/Internshala/Python Project__ File Handling and String Manipulation/Output/%s.txt' %characters[13], 'a') as f:
        for words in character_14:
                f.write(words + "\n")         
        
with open('D:/Exercise files/Internshala/Python Project__ File Handling and String Manipulation/Output/%s.txt' %characters[14], 'a') as f:
        for words in character_15:
                f.write(words + "\n") 
        
with open('D:/Exercise files/Internshala/Python Project__ File Handling and String Manipulation/Output/%s.txt' %characters[15], 'a') as f:
        for words in character_16:
                f.write(words + "\n")
        
with open('D:/Exercise files/Internshala/Python Project__ File Handling and String Manipulation/Output/%s.txt' %characters[16], 'a') as f:
        for words in character_17:
                f.write(words + "\n")

# %%
#checking if written successfully

g=open('D:/Exercise files/Internshala/Python Project__ File Handling and String Manipulation/Output/%s.txt' %characters[0], 'r')
g2=g.read()
print(g2)
g.close()
# Out:
# 16
# a
# all
# and
# at
# be
# been
# burned
# but
# cat
# crack
# crypt
# do
# fat
# fine
# fuck
# girls
# got
# had
# have
# havenâ€™t
# he
# hell
# here
# him
# i
# it
# loved
# man
# me
# minute
# much
# muscles
# must
# my
# ned
# never
# nine
# one
# ooh
# pay
# remember
# respects
# right
# robb
# seen
# show
# showed
# skulls
# soldier
# take
# teach
# that
# the
# then
# through
# to
# us
# want
# wanted
# was
# we
# what
# whatever
# where
# who
# why
# years
# you
# your
# youâ€™ll
# youâ€™ve
# â€¦
